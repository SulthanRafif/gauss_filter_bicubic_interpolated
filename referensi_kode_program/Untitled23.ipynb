# %%
import numpy as np
import cv2
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fc3b6d81-a4a6-4eb1-b07d-fd7e3c1eb957" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fc3b6d81-a4a6-4eb1-b07d-fd7e3c1eb957">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
for file_name in uploaded.keys():
    image = cv2.imread(file_name, 0)  # Read the image as grayscale
    
    # Apply the desired image processing technique (interpolation or convolution filtering)
    # Example 1: Interpolation
    interpolated_image = cv2.resize(image, None, fx=0.5, fy=0.5, interpolation=cv2.INTER_LINEAR)
    
    # Example 2: Convolution filtering
    kernel = np.ones((3, 3), np.float32) / 9  # Define a 3x3 averaging kernel
    filtered_image = cv2.filter2D(image, -1, kernel)
 
    plt.figure()
    plt.subplot(1, 4, 1)
    plt.imshow(image, cmap='gray')
    plt.title('Original')
    plt.axis('off')
    
    plt.subplot(1, 4, 2)
    plt.imshow(interpolated_image, cmap='gray')
    plt.title('Interpolated')
    plt.axis('off')
    
    # Menentukan ukuran kernel
    ksize = 3  # Ukuran kernel (harus bilangan ganjil)

    # Mengaplikasikan filter median
    filtered_image2 = cv2.medianBlur(interpolated_image, ksize)
    # Display the processed images

    plt.subplot(1, 4, 3)
    plt.imshow(filtered_image, cmap='gray')
    plt.title('median')
    plt.axis('off')
    
    # Menentukan ukuran kernel dan sigma
    ksize = 3  # Ukuran kernel
    sigma = 0  # Sigma (standar deviasi)

    # Mengaplikasikan filter Gaussian
    blurred_image = cv2.GaussianBlur(filtered_image2, (ksize, ksize), sigma)
 

    plt.subplot(1, 4, 4)
    plt.imshow(blurred_image, cmap='gray')
    plt.title('Gaussian')
    plt.axis('off')
    
    plt.show()
